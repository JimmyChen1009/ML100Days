# %% [markdown]
# ## 作業
# 礙於不是所有同學都有 GPU ，這邊的範例使用的是簡化版本的 ResNet，確保所有同學都能夠順利訓練!
#
#
# 最後一天的作業請閱讀這篇非常詳盡的[文章](https://blog.gtwang.org/programming/keras-resnet-50-pre-trained-model-build-dogs-cats-image-classification-system/)，基本上已經涵蓋了所有訓練　CNN 常用的技巧，請使用所有學過的訓練技巧，盡可能地提高 Cifar-10 的 test data 準確率，截圖你最佳的結果並上傳來完成最後一次的作業吧!
#
# 另外這些技巧在 Kaggle 上也會被許多人使用，更有人會開發一些新的技巧，例如使把預訓練在 ImageNet 上的模型當成 feature extractor 後，再拿擷取出的特徵重新訓練新的模型，這些技巧再進階的課程我們會在提到，有興趣的同學也可以[參考](https://www.kaggle.com/insaff/img-feature-extraction-with-pretrained-resnet)

# %%
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
import os

# os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
num_classes = 10

print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

# Convert class vectors to binary class matrices.
y_train = tf.keras.utils.to_categorical(y_train, num_classes)
y_test = tf.keras.utils.to_categorical(y_test, num_classes)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 2s 0us/step
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples

# %%
batch_size = 64
epochs = 50

# %%
early_stopping = EarlyStopping(monitor='val_accuracy', patience=5)

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), padding='same',
                 input_shape=x_train.shape[1:]))
model.add(Activation('relu'))
model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.2))

model.add(Conv2D(64, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.2))

model.add(Conv2D(128, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(Conv2D(128, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.2))

model.add(Flatten())
model.add(Dense(256))
model.add(Activation('relu'))
model.add(Dropout(0.25))
model.add(Dense(num_classes))
model.add(Activation('softmax'))
model.summary()

model.compile(loss='categorical_crossentropy',
              optimizer=Adam(learning_rate=1e-4),
              metrics=['accuracy'])
augment_generator = ImageDataGenerator(rotation_range=10, width_shift_range=0.1, height_shift_range=0.1, horizontal_flip=True)

history = model.fit_generator(augment_generator.flow(x_train, y_train, batch_size=batch_size),
                    steps_per_epoch=int(len(x_train)/batch_size), # 一個 epochs 要執行幾次 update，通常是資料量除以 batch size
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_test, y_test),
                    callbacks=[early_stopping])
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  activation (Activation)     (None, 32, 32, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 30, 30, 32)        9248
#
#  activation_1 (Activation)   (None, 30, 30, 32)        0
#
#  max_pooling2d (MaxPooling2  (None, 15, 15, 32)        0
#  D)
#
#  dropout (Dropout)           (None, 15, 15, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 15, 15, 64)        18496
#
#  activation_2 (Activation)   (None, 15, 15, 64)        0
#
#  conv2d_3 (Conv2D)           (None, 13, 13, 64)        36928
#
#  activation_3 (Activation)   (None, 13, 13, 64)        0
#
#  max_pooling2d_1 (MaxPoolin  (None, 6, 6, 64)          0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 6, 6, 64)          0
#
#  conv2d_4 (Conv2D)           (None, 6, 6, 128)         73856
#
#  activation_4 (Activation)   (None, 6, 6, 128)         0
#
#  conv2d_5 (Conv2D)           (None, 4, 4, 128)         147584
#
#  activation_5 (Activation)   (None, 4, 4, 128)         0
#
#  max_pooling2d_2 (MaxPoolin  (None, 2, 2, 128)         0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 2, 2, 128)         0
#
#  flatten (Flatten)           (None, 512)               0
#
#  dense (Dense)               (None, 256)               131328
#
#  activation_6 (Activation)   (None, 256)               0
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 10)                2570
#
#  activation_7 (Activation)   (None, 10)                0
#
# =================================================================
# Total params: 420906 (1.61 MB)
# Trainable params: 420906 (1.61 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# <ipython-input-5-08d0a8d1b71d>:37: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(augment_generator.flow(x_train, y_train, batch_size=batch_size),
# 781/781 [==============================] - 47s 44ms/step - loss: 1.9357 - accuracy: 0.2669 - val_loss: 1.6364 - val_accuracy: 0.3928
# Epoch 2/50
# 781/781 [==============================] - 33s 42ms/step - loss: 1.6635 - accuracy: 0.3818 - val_loss: 1.5275 - val_accuracy: 0.4312
# Epoch 3/50
# 781/781 [==============================] - 34s 43ms/step - loss: 1.5410 - accuracy: 0.4313 - val_loss: 1.4442 - val_accuracy: 0.4693
# Epoch 4/50
# 781/781 [==============================] - 33s 42ms/step - loss: 1.4684 - accuracy: 0.4586 - val_loss: 1.3130 - val_accuracy: 0.5260
# Epoch 5/50
# 781/781 [==============================] - 34s 43ms/step - loss: 1.4018 - accuracy: 0.4879 - val_loss: 1.2334 - val_accuracy: 0.5510
# Epoch 6/50
# 781/781 [==============================] - 32s 41ms/step - loss: 1.3449 - accuracy: 0.5125 - val_loss: 1.2942 - val_accuracy: 0.5359
# Epoch 7/50
# 781/781 [==============================] - 34s 43ms/step - loss: 1.2961 - accuracy: 0.5336 - val_loss: 1.1959 - val_accuracy: 0.5694
# Epoch 8/50
# 781/781 [==============================] - 34s 44ms/step - loss: 1.2569 - accuracy: 0.5487 - val_loss: 1.1885 - val_accuracy: 0.5827
# Epoch 9/50
# 781/781 [==============================] - 34s 43ms/step - loss: 1.2147 - accuracy: 0.5616 - val_loss: 1.1397 - val_accuracy: 0.5961
# Epoch 10/50
# 781/781 [==============================] - 33s 42ms/step - loss: 1.1795 - accuracy: 0.5803 - val_loss: 1.0356 - val_accuracy: 0.6350
# Epoch 11/50
# 781/781 [==============================] - 33s 43ms/step - loss: 1.1452 - accuracy: 0.5937 - val_loss: 1.0334 - val_accuracy: 0.6306
# Epoch 12/50
# 781/781 [==============================] - 32s 42ms/step - loss: 1.1208 - accuracy: 0.6001 - val_loss: 1.1114 - val_accuracy: 0.6118
# Epoch 13/50
# 781/781 [==============================] - 33s 42ms/step - loss: 1.0951 - accuracy: 0.6114 - val_loss: 0.9661 - val_accuracy: 0.6559
# Epoch 14/50
# 781/781 [==============================] - 34s 43ms/step - loss: 1.0695 - accuracy: 0.6209 - val_loss: 0.9539 - val_accuracy: 0.6646
# Epoch 15/50
# 781/781 [==============================] - 34s 43ms/step - loss: 1.0442 - accuracy: 0.6270 - val_loss: 0.9227 - val_accuracy: 0.6706
# Epoch 16/50
# 781/781 [==============================] - 33s 43ms/step - loss: 1.0249 - accuracy: 0.6386 - val_loss: 0.9168 - val_accuracy: 0.6753
# Epoch 17/50
# 781/781 [==============================] - 33s 42ms/step - loss: 1.0076 - accuracy: 0.6431 - val_loss: 0.9477 - val_accuracy: 0.6668
# Epoch 18/50
# 781/781 [==============================] - 34s 43ms/step - loss: 0.9830 - accuracy: 0.6515 - val_loss: 0.8792 - val_accuracy: 0.6875
# Epoch 19/50
# 781/781 [==============================] - 32s 41ms/step - loss: 0.9667 - accuracy: 0.6614 - val_loss: 0.8893 - val_accuracy: 0.6844
# Epoch 20/50
# 781/781 [==============================] - 34s 43ms/step - loss: 0.9520 - accuracy: 0.6657 - val_loss: 0.9407 - val_accuracy: 0.6712
# Epoch 21/50
# 781/781 [==============================] - 32s 41ms/step - loss: 0.9307 - accuracy: 0.6732 - val_loss: 0.8713 - val_accuracy: 0.6968
# Epoch 22/50
# 781/781 [==============================] - 33s 43ms/step - loss: 0.9169 - accuracy: 0.6773 - val_loss: 0.9250 - val_accuracy: 0.6833
# Epoch 23/50
# 781/781 [==============================] - 33s 42ms/step - loss: 0.9036 - accuracy: 0.6828 - val_loss: 0.7915 - val_accuracy: 0.7222
# Epoch 24/50
# 781/781 [==============================] - 33s 43ms/step - loss: 0.8931 - accuracy: 0.6849 - val_loss: 0.8241 - val_accuracy: 0.7124
# Epoch 25/50
# 781/781 [==============================] - 34s 43ms/step - loss: 0.8772 - accuracy: 0.6905 - val_loss: 0.7691 - val_accuracy: 0.7310
# Epoch 26/50
# 781/781 [==============================] - 33s 43ms/step - loss: 0.8649 - accuracy: 0.6951 - val_loss: 0.8065 - val_accuracy: 0.7207
# Epoch 27/50
# 781/781 [==============================] - 32s 41ms/step - loss: 0.8465 - accuracy: 0.7021 - val_loss: 0.7902 - val_accuracy: 0.7245
# Epoch 28/50
# 781/781 [==============================] - 33s 42ms/step - loss: 0.8385 - accuracy: 0.7055 - val_loss: 0.8034 - val_accuracy: 0.7206
# Epoch 29/50
# 781/781 [==============================] - 34s 44ms/step - loss: 0.8270 - accuracy: 0.7117 - val_loss: 0.7621 - val_accuracy: 0.7278
# Epoch 30/50
# 781/781 [==============================] - 32s 41ms/step - loss: 0.8127 - accuracy: 0.7145 - val_loss: 0.7978 - val_accuracy: 0.7235

# %%
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 0.7977738380432129
# Test accuracy: 0.7235000133514404
