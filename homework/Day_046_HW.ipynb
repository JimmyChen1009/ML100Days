# %% [markdown]
# ### 作業
# 目前已經學過許多的模型，相信大家對整體流程應該比較掌握了，這次作業請改用**手寫辨識資料集**，步驟流程都是一樣的，請試著自己撰寫程式碼來完成所有步驟

# %%
import numpy as np
from sklearn import datasets, metrics
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import train_test_split

# %%
digits=datasets.load_digits()
x_train, x_test, y_train, y_test=train_test_split(digits.data, digits.target, test_size=0.25, random_state=42)
x_train.shape
# Out:
# (1347, 64)

# %%
model=GradientBoostingClassifier(learning_rate=0.1, n_estimator=100, random_state=42)
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
acc=metrics.accuracy_score(y_test, y_pred)
print("Acuuracy: ", acc)
# Out:
# Acuuracy:  0.9711111111111111

# %% [markdown]
# ### Number of estimator

# %%
maxTreeList=list(range(1, 50))
accList=[]

for num_tree in maxTreeList:
    model=GradientBoostingClassifier(n_estimators=num_tree, random_state=42)
    model.fit(x_train, y_train)
    y_pred=model.predict(x_test)
    print("Number of trees: {}, Accuracy: {}".format(num_tree, round(metrics.accuracy_score(y_test, y_pred), 2)))
    accList.append(metrics.accuracy_score(y_test, y_pred))
# Out:
# Number of trees: 1, Accuracy: 0.83
# Number of trees: 2, Accuracy: 0.85
# Number of trees: 3, Accuracy: 0.86
# Number of trees: 4, Accuracy: 0.88
# Number of trees: 5, Accuracy: 0.89
# Number of trees: 6, Accuracy: 0.88
# Number of trees: 7, Accuracy: 0.89
# Number of trees: 8, Accuracy: 0.9
# Number of trees: 9, Accuracy: 0.9
# Number of trees: 10, Accuracy: 0.91
# Number of trees: 11, Accuracy: 0.92
# Number of trees: 12, Accuracy: 0.92
# Number of trees: 13, Accuracy: 0.92
# Number of trees: 14, Accuracy: 0.93
# Number of trees: 15, Accuracy: 0.93
# Number of trees: 16, Accuracy: 0.94
# Number of trees: 17, Accuracy: 0.94
# Number of trees: 18, Accuracy: 0.94
# Number of trees: 19, Accuracy: 0.93
# Number of trees: 20, Accuracy: 0.94
# Number of trees: 21, Accuracy: 0.94
# Number of trees: 22, Accuracy: 0.94
# Number of trees: 23, Accuracy: 0.94
# Number of trees: 24, Accuracy: 0.94
# Number of trees: 25, Accuracy: 0.94
# Number of trees: 26, Accuracy: 0.94
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(maxTreeList, accList)
plt.xlabel("Number of Trees")
plt.ylabel("Accuracy")
plt.show()

# %% [markdown]
# ### Learning rate

# %%
LearningRateList=[0.0001,0.001,0.01,0.1,1,10]
accList=[]

for lr in LearningRateList:
    model=GradientBoostingClassifier(learning_rate=lr, n_estimators=100, random_state=42)
    model.fit(x_train, y_train)
    y_pred=model.predict(x_test)
    print("Number of trees: {}, Accuracy: {}".format(num_tree, round(metrics.accuracy_score(y_test, y_pred), 2)))
    accList.append(metrics.accuracy_score(y_test, y_pred))
# Out:
# Number of trees: 49, Accuracy: 0.51
# Number of trees: 49, Accuracy: 0.85
# Number of trees: 49, Accuracy: 0.91
# Number of trees: 49, Accuracy: 0.97
# Number of trees: 49, Accuracy: 0.95
# Number of trees: 49, Accuracy: 0.03

# %%
import matplotlib.pyplot as plt
plt.plot(accList)
plt.xticks(np.arange(0,6),LearningRateList)
plt.xlabel("Learning Rate")
plt.ylabel("Accuracy")
plt.show()
